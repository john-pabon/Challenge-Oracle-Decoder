# %% [markdown]
# <a href="https://colab.research.google.com/github/john-pabon/Challenge-Oracle-Decoder/blob/main/ImportandoArchivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 1 -Leyendo archivos CSV

# %% [markdown]
# ## Importando archivos CSV

# %%
import pandas as pd

# %%
#Crear variable para guardar los datos del archivo, despues de leerlo
datos = pd.read_csv('/content/superstore_data.csv')
datos.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
#Muestra los primero cinco datos
datos.head(5)
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
# que pasa si el archivo no esta separado por comas sino por punto y comas
datos_punto_coma = pd.read_csv('/content/superstore_data_punto_coma.csv')
datos_punto_coma.head()
# Out:
#   Id;Year_Birth;Education;Marital_Status;Income;Kidhome;Teenhome;Dt_Customer;Recency;MntWines;MntFruits;MntMeatProducts;MntFishProducts;MntSweetProducts;MntGoldProds;NumDealsPurchases;NumWebPurchases;NumCatalogPurchases;NumStorePurchases;NumWebVisitsMonth;Response;Complain
# 0  1826;1970;Graduation;Divorced;84835;0;0;6/16/2...
# 1  1;1961;Graduation;Single;57091;0;0;6/15/2014;0...
# 2  10476;1958;Graduation;Married;67267;0;1;5/13/2...
# 3  1386;1967;Graduation;Together;32474;1;1;11/5/2...
# 4  5371;1989;Graduation;Single;21474;1;0;8/4/2014...

# %%
#Como solucionar la lecturaras de datos por punto y coma con la funcion sep
datos_punto_coma = pd.read_csv('/content/superstore_data_punto_coma.csv', sep =';')
datos_punto_coma.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
#funcion nrows para decir cuantas filas quiere ver
datos_primeras_lineas = pd.read_csv('superstore_data.csv', nrows = 5)
datos_primeras_lineas
# Out:
#       Id  Year_Birth   Education Marital_Status  Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced   84835        0         0
# 1      1        1961  Graduation         Single   57091        0         0
# 2  10476        1958  Graduation        Married   67267        0         1
# 3   1386        1967  Graduation       Together   32474        1         1
# 4   5371        1989  Graduation         Single   21474        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
#    MntGoldProds  NumDealsPurchases  NumWebPurchases  NumCatalogPurchases  \
# ...

# %%
#funcion usecols para seleccionar  que tipo de columnas  quiero ver
datos_seleccion = pd.read_csv('superstore_data.csv', usecols = ['Id','Year_Birth','Income'])
datos_seleccion
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
#funcion usecols para seleccionar la posicion de las  columnas quiero ver
datos_seleccion = pd.read_csv('superstore_data.csv', usecols = [0,1,4])
datos_seleccion
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
#Exportar archivos a CSV
datos_seleccion.to_csv('clientes_mercado.csv')

# %%
#Abrir archivo
clientes_mercado = pd.read_csv('clientes_mercado.csv')
clientes_mercado.head()
# Out:
#    Unnamed: 0     Id  Year_Birth   Income
# 0           0   1826        1970  84835.0
# 1           1      1        1961  57091.0
# 2           2  10476        1958  67267.0
# 3           3   1386        1967  32474.0
# 4           4   5371        1989  21474.0

# %%
datos_seleccion.to_csv('datos_mercado.csv', index =False)

# %%
#Aparece una columna extra llamada indice y necesitamos removerla
datos_mercado = pd.read_csv('datos_mercado.csv')
datos_mercado
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# Es hora de que pongas a prueba los conocimientos desarrollados durante la clase. Disponemos de un archivo en formato CSV, el cual se obtuvo de la página Información de Salud (TABNET) - DATASUS. Este archivo contiene los gastos hospitalarios públicos de cada una de las Unidades de la Federación Brasileña desde enero de 2008 hasta marzo de 2021.
#
# Su desafío aquí será leer este archivo usando la función read_csv de la biblioteca Pandas. Se deben agregar algunos parámetros para que la lectura se realice correctamente. Entonces, aquí hay algunos consejos:
#
# Asegúrese de que el archivo CSV esté separado por una coma o punto y coma.
# La codificación del archivo es ISO-8859-1.
# Las primeras tres líneas del archivo se pueden ignorar, ya que el encabezado sólo comienza en la cuarta línea.
# Las últimas 9 líneas también se pueden ignorar, ya que son sólo información sobre dónde se tomaron los datos.
# Para eliminar las últimas líneas es necesario agregar el parámetro engine='python'.
# ¿Comenzamos?

# %%
#Crear variable para guardar los datos del archivo, despues de leerlo
datos = pd.read_csv('datos_mercado.csv')

# %% [markdown]
# # Aula 2 Leyendo archivos Excel

# %% [markdown]
# ## Importe archivos Excel

# %%
import pandas as pd

# %%
archivo = 'emisiones_CO2.xlsx'

# %%
# leer archivo
pd.read_excel(archivo)
# Out:
#              País ISO 3166-1 alpha-3   Año         Total        Carbón  \
# 0      Afganistán                AFG  1750  0.000000e+00           NaN
# 1      Afganistán                AFG  1751  0.000000e+00           NaN
# 2      Afganistán                AFG  1752  0.000000e+00           NaN
# 3      Afganistán                AFG  1753  0.000000e+00           NaN
# 4      Afganistán                AFG  1754  0.000000e+00           NaN
# ...           ...                ...   ...           ...           ...
# 63099      Global                WLD  2017  3.609674e+10  1.450697e+10
# 63100      Global                WLD  2018  3.682651e+10  1.474683e+10
# 63101      Global                WLD  2019  3.708256e+10  1.472598e+10
# 63102      Global                WLD  2020  3.526409e+10  1.417456e+10
# 63103      Global                WLD  2021  3.712385e+10  1.497960e+10
#
#              Aceite           Gas       Cemento        Quema        Otros  \
# ...

# %%
# convertirlo el metodo dato frame
datos_co2 = pd.read_excel(archivo)

# %%
datos_co2.head(5)
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    0.0     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    0.0     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    0.0     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    0.0     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    0.0     NaN     NaN  NaN      NaN
#
#    Quema  Otros  Per Capita
# 0    NaN    NaN         NaN
# 1    NaN    NaN         NaN
# 2    NaN    NaN         NaN
# 3    NaN    NaN         NaN
# 4    NaN    NaN         NaN

# %%
# Ver cual hoja o sheer estoy viendo
pd.ExcelFile(archivo).sheet_names
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %%
# Para ver la segunda hoja o tercera hoja
percapita = pd.read_excel(archivo, sheet_name = 'emisiones_percapita')

# %%
# Muestra las primeras cinco lineas
percapita.head()
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    NaN     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    NaN     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    NaN     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    NaN     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    NaN     NaN     NaN  NaN      NaN
#
#    Quema  Otros
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN

# %%
# Muestra los ultimos cinco reistros
percapita.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 63099  Global                WLD  2017  4749682.0  1908857.0  1610910.0
# 63100  Global                WLD  2018  4792753.0  1919213.0  1596350.0
# 63101  Global                WLD  2019  4775633.0  1896468.0  1589920.0
# 63102  Global                WLD  2020  4497423.0  1807760.0  1427353.0
# 63103  Global                WLD  2021  4693699.0  1893923.0  1496614.0
#
#              Gas   Cemento    Quema    Otros
# 63099   940144.0  198416.0  51579.0  39776.0
# 63100   979965.0  204225.0  53634.0  39366.0
# 63101   984878.0  208309.0  56569.0  39490.0
# 63102   963695.0  208844.0  51981.0  37789.0
# 63103  1001585.0  211472.0  52663.0  37443.0

# %%
# Muestra registros aleatorios
percapita.sample(5)
# Out:
#                               País ISO 3166-1 alpha-3   Año      Total  \
# 52109                    Sudáfrica                ZAF  1907        NaN
# 46674                      Reunión                REU  1912        NaN
# 9934   República De África Central                CAF  1892        NaN
# 26333                      Irlanda                IRL  1971  7569274.0
# 772                        Argelia                DZA  1978  3542025.0
#
#           Carbón     Aceite        Gas   Cemento      Quema  Otros
# 52109        NaN        NaN        NaN       NaN        NaN    NaN
# 46674        NaN        NaN        NaN       NaN        NaN    NaN
# 9934         NaN        NaN        NaN       NaN        NaN    NaN
# 26333  2768918.0  4549465.0        0.0  250892.0        0.0    NaN
# 772      32416.0   746612.0  1352962.0   74942.0  1335092.0    NaN

# %%
# Verificar las fuentes
fuentes = pd.read_excel(archivo, sheet_name='fuentes')

# %%
fuentes.tail()
# Out:
#          País ISO 3166-1 alpha-3   Año                                 Total  \
# 63099  Global                WLD  2017  CDIAC 2022, BP, and Sum of countries
# 63100  Global                WLD  2018  CDIAC 2022, BP, and Sum of countries
# 63101  Global                WLD  2019  CDIAC 2022, BP, and Sum of countries
# 63102  Global                WLD  2020  CDIAC 2022, BP, and Sum of countries
# 63103  Global                WLD  2021  CDIAC 2022, BP, and Sum of countries
#
#                   Carbón             Aceite                Gas        Cemento  \
# 63099  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63100  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63101  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63102  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
# 63103  CDIAC 2022 and BP  CDIAC 2022 and BP  CDIAC 2022 and BP  Andrew cement
#
# ...

# %%
# Escoger las primeras cuatro columnas
intervalo = pd.read_excel(archivo, sheet_name ='emisiones_C02', usecols = 'A:E')

# %%
# leer la variable
intervalo
# Out:
#              País ISO 3166-1 alpha-3   Año         Total        Carbón
# 0      Afganistán                AFG  1750  0.000000e+00           NaN
# 1      Afganistán                AFG  1751  0.000000e+00           NaN
# 2      Afganistán                AFG  1752  0.000000e+00           NaN
# 3      Afganistán                AFG  1753  0.000000e+00           NaN
# 4      Afganistán                AFG  1754  0.000000e+00           NaN
# ...           ...                ...   ...           ...           ...
# 63099      Global                WLD  2017  3.609674e+10  1.450697e+10
# 63100      Global                WLD  2018  3.682651e+10  1.474683e+10
# 63101      Global                WLD  2019  3.708256e+10  1.472598e+10
# 63102      Global                WLD  2020  3.526409e+10  1.417456e+10
# 63103      Global                WLD  2021  3.712385e+10  1.497960e+10
#
# [63104 rows x 5 columns]

# %%
#Leer las filas
intervalo2 = pd.read_excel(archivo, sheet_name ='emisiones_C02', usecols = 'A:E', nrows =10)

# %%
intervalo2
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón
# 0  Afganistán                AFG  1750      0     NaN
# 1  Afganistán                AFG  1751      0     NaN
# 2  Afganistán                AFG  1752      0     NaN
# 3  Afganistán                AFG  1753      0     NaN
# 4  Afganistán                AFG  1754      0     NaN
# 5  Afganistán                AFG  1755      0     NaN
# 6  Afganistán                AFG  1756      0     NaN
# 7  Afganistán                AFG  1757      0     NaN
# 8  Afganistán                AFG  1758      0     NaN
# 9  Afganistán                AFG  1759      0     NaN

# %%
# Exportar archivo a archivo Excel
intervalo.to_excel('co2_percapita.xlsx', index = False)

# %%
pd.read_excel('co2_percapita.xlsx')
# Out:
#              País ISO 3166-1 alpha-3   Año         Total        Carbón
# 0      Afganistán                AFG  1750  0.000000e+00           NaN
# 1      Afganistán                AFG  1751  0.000000e+00           NaN
# 2      Afganistán                AFG  1752  0.000000e+00           NaN
# 3      Afganistán                AFG  1753  0.000000e+00           NaN
# 4      Afganistán                AFG  1754  0.000000e+00           NaN
# ...           ...                ...   ...           ...           ...
# 63099      Global                WLD  2017  3.609674e+10  1.450697e+10
# 63100      Global                WLD  2018  3.682651e+10  1.474683e+10
# 63101      Global                WLD  2019  3.708256e+10  1.472598e+10
# 63102      Global                WLD  2020  3.526409e+10  1.417456e+10
# 63103      Global                WLD  2021  3.712385e+10  1.497960e+10
#
# [63104 rows x 5 columns]

# %% [markdown]
# ## Leyendo datos de Google Sheets online

# %% [markdown]
# ### link https://docs.google.com/spreadsheets/d/1ypx_w7PbTVDMySchayKR9ctX2kKNJE521jVahohg094/edit?usp=sharing

# %%
sheet_id = '1ypx_w7PbTVDMySchayKR9ctX2kKNJE521jVahohg094'
url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
# leer archivo
url
# Out:
# 'https://docs.google.com/spreadsheets/d/1ypx_w7PbTVDMySchayKR9ctX2kKNJE521jVahohg094/gviz/tq?tqx=out:csv&sheet'

# %%
datos_co2_sheets = pd.read_csv(url)

# %% [markdown]
# ####  significa que estás intentando acceder a un archivo de Google Sheets que no está disponible públicamente. Es decir, necesitas permisos para acceder a él.

# %% [markdown]
# #### ¿Cómo solucionar este problema?
# Tienes dos opciones:
# Opción 1: Hacer el archivo público
# Abre la hoja de cálculo en Google Sheets.
#
# Haz clic en el botón “Compartir” (arriba a la derecha).
#
# En la ventana emergente, cambia los permisos a:
#
# “Cualquiera con el enlace” puede “Ver”.
#
# Luego usa el siguiente formato para acceder:
#
# Opción 2: Descargar el archivo como CSV y cargarlo localmente
# Abre la hoja en Google Sheets.
#
# Ve a Archivo > Descargar > Valores separados por comas (.csv).
#
# En tu notebook Colab, sube el archivo:

# %% [markdown]
# #### ¿Qué es esto?
# Es una f-string de Python que construye dinámicamente una URL para descargar una hoja de cálculo de Google Sheets como un archivo CSV.
#
# 🧩 Parte por parte:
# 1. f'...'
# Es una f-string (formato de cadena). Permite incluir variables dentro de una cadena de texto usando llaves {}.
#
# 2. 'https://docs.google.com/spreadsheets/d/'
# Esta es la parte inicial de la URL que apunta al sitio de Google Sheets.
#
# 3. {sheet_id}
# Aquí se inserta el ID del documento de Google Sheets.
#
# Ejemplo: '1ypx_w7PbTVDMySchayKR9ctX2kKNJE521jVahohg094'
#
# Este ID aparece en la URL del documento de Google:
#
# latex
# Copy
# Edit
# https://docs.google.com/spreadsheets/d/1ypx_w7PbTVDMySchayKR9ctX2kKNJE521jVahohg094/edit
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                                           → Este es el ID
# 4. /gviz/tq?tqx=out:csv
# Esta parte le indica a Google que queremos los datos en formato CSV.
#
# gviz/tq es una interfaz especial de Google que permite consultar datos.
#
# tqx=out:csv dice: "Queremos la salida (out) en formato CSV".
#
# 5. &sheet={sheet_name}
# Aquí se inserta el nombre de la hoja dentro del archivo.
#
# Ejemplo: si tu hoja se llama "Ventas_2024", esa sería la variable {sheet_name}.
#
# Asegúrate de que coincida exactamente con el nombre que aparece en la pestaña de la hoja.

# %%
#solucion 1
import pandas as pd

sheet_id = '1ypx_w7PbTVDMySchayKR9ctX2kKNJE521jVahohg094'
sheet_name = 'NombreDeTuHoja'  # <-- reemplaza con el nombre real de tu hoja

url = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'
datos_co2_sheets = pd.read_csv(url)

# %%
datos_co2_sheets
# Out:
#              País ISO 3166-1 alpha-3   Año           Total          Carbón  \
# 0      Afganistán                AFG  1750               0             NaN
# 1      Afganistán                AFG  1751               0             NaN
# 2      Afganistán                AFG  1752               0             NaN
# 3      Afganistán                AFG  1753               0             NaN
# 4      Afganistán                AFG  1754               0             NaN
# ...           ...                ...   ...             ...             ...
# 63099      Global                WLD  2017  36,096,739,276  14,506,973,805
# 63100      Global                WLD  2018  36,826,506,600  14,746,830,688
# 63101      Global                WLD  2019  37,082,558,969  14,725,978,025
# 63102      Global                WLD  2020  35,264,085,734  14,174,564,010
# 63103      Global                WLD  2021  37,123,850,352  14,979,598,083
#
# ...

# %%
# Quiero ver la segunda hoja
sheet_id = '1ypx_w7PbTVDMySchayKR9ctX2kKNJE521jVahohg094'
sheet_name = 'NombreDeTuHojaemisiones_percapita'  # <-- reemplaza con el nombre real de tu hoja

url_percapita= f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
percapita_sheets = pd.read_csv(url_percapita)

# %%
percapita_sheets
# Out:
#              País ISO 3166-1 alpha-3   Año           Total          Carbón  \
# 0      Afganistán                AFG  1750               0             NaN
# 1      Afganistán                AFG  1751               0             NaN
# 2      Afganistán                AFG  1752               0             NaN
# 3      Afganistán                AFG  1753               0             NaN
# 4      Afganistán                AFG  1754               0             NaN
# ...           ...                ...   ...             ...             ...
# 63099      Global                WLD  2017  36,096,739,276  14,506,973,805
# 63100      Global                WLD  2018  36,826,506,600  14,746,830,688
# 63101      Global                WLD  2019  37,082,558,969  14,725,978,025
# 63102      Global                WLD  2020  35,264,085,734  14,174,564,010
# 63103      Global                WLD  2021  37,123,850,352  14,979,598,083
#
# ...

# %%
# Quiero ver la segunda hoja
sheet_id = '1ypx_w7PbTVDMySchayKR9ctX2kKNJE521jVahohg094'
sheet_name = 'fuentes'  # <-- reemplaza con el nombre real de tu hoja

url_fuentes= f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
fuentes_sheets =pd.read_csv(url_fuentes)

# %%
fuentes_sheets
# Out:
#              País ISO 3166-1 alpha-3   Año  \
# 0      Afganistán                AFG  1750
# 1      Afganistán                AFG  1751
# 2      Afganistán                AFG  1752
# 3      Afganistán                AFG  1753
# 4      Afganistán                AFG  1754
# ...           ...                ...   ...
# 63099      Global                WLD  2017
# 63100      Global                WLD  2018
# 63101      Global                WLD  2019
# 63102      Global                WLD  2020
# 63103      Global                WLD  2021
#
#                                       Total             Carbón  \
# 0                                    [NONE]             [NONE]
# 1                                    [NONE]             [NONE]
# 2                                    [NONE]             [NONE]
# 3                                    [NONE]             [NONE]
# 4                                    [NONE]             [NONE]
# ...

# %% [markdown]
# ##3 Desafio

# %% [markdown]
# #### Es hora de que pongas a prueba los conocimientos desarrollados durante la clase. Tenemos un link de Google Sheets que contiene datos importantes sobre las emisiones de dióxido de carbono en todo el mundo. El conjunto de datos se obtuvo de Kaggle y consta de las emisiones de CO2 per cápita de todos los países del mundo entre 1990 y 2019.
#
# En este desafío, tu función es leer este link de Google Sheets y luego guardar el DataFrame obtenido en formato CSV. ¿Listo para comenzar?

# %% [markdown]
# # Aula 3 Leyendo archivos JSON

# %% [markdown]
# ## Importar archivos JSON

# %%
#Importar librerias
import pandas as pd

# %%
#Leer archivo
datos_pacientes = pd.read_json('pacientes.json')

# %%
datos_pacientes
# Out:
#      ID_paciente Enfermedad_corazon    IMC Fumador Consumo_alcohol AVC  \
# 0              0                 No  16.60      Sí              No  No
# 1              1                 No  20.34      No              No  Sí
# 2              2                 No  26.58      Sí              No  No
# 3              3                 No  24.21      No              No  No
# 4              4                 No  23.71      No              No  No
# ..           ...                ...    ...     ...             ...  ..
# 995          995                 No  28.29      Sí              No  No
# 996          996                 No  25.69      Sí              No  No
# 997          997                 Sí  26.99      No              No  No
# 998          998                 No  44.29      No              No  No
# 999          999                 No  25.83      No              No  No
#
#      Salud_fisica  Salud_mental Dificultad_caminar Sexo_biologico Rango_edad  \
# ...

# %%
# columnas con informacion anidada
datos_pacientes_2 = pd.read_json('pacientes_2.json')

# %%
datos_pacientes_2
# Out:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Rango_edad': '55-59', 'Sexo_biol...
# 1  {'ID': '02', 'Rango_edad': '80 ó +', 'Sexo_bio...
# 2  {'ID': '03', 'Rango_edad': '65-69', 'Sexo_biol...

# %% [markdown]
# ## Normailizando archivos JSON

# %%
df_normailizado = pd.json_normalize(datos_pacientes_2['Pacientes'])

# %%
df_normailizado
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# ### Escribiendo archivos JSON

# %%
df_normailizado.to_json('historico_pacientes_norm.json')

# %%
pd.read_json('historico_pacientes_norm.json')
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0   1      55-59          Mujer  Blanca  16.60      Sí              No
# 1   2     80 ó +          Mujer  Blanca  20.34      No              No
# 2   3      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %% [markdown]
# ### Para saber más: obteniendo archivos JSON de APIs

# %% [markdown]
# ### Para obtener datos en formato JSON podemos utilizar una API (Application Programming Interface). Es una interfaz de programación de aplicaciones que permite la comunicación entre diferentes programas o sistemas.
#
# Hay varios formatos que se pueden utilizar en las API y uno de los más comunes es JSON (JavaScript Object Notation). JSON es un formato ligero para intercambiar información entre sistemas que utiliza la notación basada en objetos de JavaScript.
#
# Tenemos la siguiente situación-problema:
#
# “Una empresa de alimentos saludables tiene problemas con la popularidad de sus productos. A pesar de ofrecer opciones saludables, muchos clientes se muestran reacios a comprar los productos debido a la falta de información sobre los valores nutricionales de las frutas que se utilizan en la producción de alimentos”.
#
# Ante esta situación podemos acceder a una API llamada Fruitvice para recopilar información detallada sobre los valores nutricionales de las frutas que se utilizan en los productos. Con esta información, la empresa podrá actualizar sus empaques y materiales de marketing para resaltar los valores nutricionales de las frutas y así atraer más clientes que buscan opciones saludables. Además, la empresa puede utilizar la información para desarrollar nuevos productos que satisfagan aún más las necesidades nutricionales de su clientela.
#
# Una forma común de acceder a las API es a través de la biblioteca requests. Para eso, también es necesario importar el módulo json:

# %%
import requests
import json

# %%
#Los datos de API Fruitvice se obtendrán con la función request.get('url').
#Dentro de ella pasamos la dirección API seguida de api/fruit/all para obtener los datos de todas las frutas.
datos_frutas = requests.get('https://fruityvice.com/api/fruit/all')

# %%
#Conseguimos recuperar los resultados utilizando la función json.loads().
#Para ello es necesario pasar la variable datos_frutas, previamente creada
#con el atributo text que devuelve el contenido de la respuesta.
resultado = json.loads(datos_frutas.text)

# %%
#Luego podemos obtener una vista previa del DataFrame.
tabla =pd.DataFrame(resultado)

# %%
tabla
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %% [markdown]
# # Aula 4 Leyendo paginas en HTML e XML

# %% [markdown]
# ## Importando paginas web

# %%
import pandas as pd

# %%
datos_html = pd.read_html('peliculas_wikipedia.html')

# %%
datos_html
# Out:
# [       0                      1
#  0   1998             100 Movies
#  1   1999              100 Stars
#  2   2000             100 Laughs
#  3   2001            100 Thrills
#  4   2002           100 Passions
#  5   2003  100 Heroes & Villains
#  6   2004              100 Songs
#  7   2005       100 Movie Quotes
#  8   2005              25 Scores
#  9   2006             100 Cheers
#  10  2006            25 Musicals
#  11  2007   100 Movies (Updated)
#  12  2008        AFI's 10 Top 10
#  13   vte                    vte,
#                              Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
# ...

# %%
type(datos_html)
# Out:
# list

# %%
len(datos_html)
# Out:
# 3

# %%
top_peliculas = datos_html[1]

# %%
top_peliculas
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %% [markdown]
# ### Escribiendo archivos e HTML

# %%
type(top_peliculas)
# Out:
# pandas.core.frame.DataFrame

# %%
top_peliculas.to_html('top_peliculas.html', index=False)

# %%
#Leer archivo
pd.read_html('top_peliculas.html')
# Out:
# [                            Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
#  ..                           ...           ...                   ...
#  95                 The Searchers          1956             John Ford
#  96              Bringing Up Baby          1938          Howard Hawks
#  97                    Unforgiven          1992        Clint Eastwood
#  98  Guess Who's Coming to Dinner          1967        Stanley Kramer
#  99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                        Production companies  Rank
#  0                       RKO Radio Pictures     1
# ...

# %%
top_peliculas.to_csv('top_peliculas_1998.csv', index=False)

# %%
datos = pd.read_csv('top_peliculas_1998.csv')

# %%
datos
# Out:
#                             Film  Release year              Director  \
# 0                   Citizen Kane          1941          Orson Welles
# 1                     Casablanca          1942        Michael Curtiz
# 2                  The Godfather          1972  Francis Ford Coppola
# 3             Gone with the Wind          1939        Victor Fleming
# 4             Lawrence of Arabia          1962            David Lean
# ..                           ...           ...                   ...
# 95                 The Searchers          1956             John Ford
# 96              Bringing Up Baby          1938          Howard Hawks
# 97                    Unforgiven          1992        Clint Eastwood
# 98  Guess Who's Coming to Dinner          1967        Stanley Kramer
# 99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                       Production companies  Rank
# 0                       RKO Radio Pictures     1
# ...

# %% [markdown]
# ### Leyendo / escribiendo archivos XML

# %%
#Leer archivo y convertirlo en dataframe
datos_imb = pd.read_xml('imdb_top_1000.xml')

# %%
datos_imb.head(3)
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
#
#                                             Overview  Meta_score  \
# 0  Two imprisoned men bond over a number of years...        80.0
# 1  An organized crime dynasty's aging patriarch t...       100.0
# 2  When the menace known as the Joker wreaks havo...        84.0
#
# ...

# %%
# Exportar archivo
datos_imb.to_xml('peliculas_imdb.xml')

# %% [markdown]
# ### Desafío: leer una tabla de una página web

# %% [markdown]
# ### Es el momento de poner a prueba los conocimientos desarrollados durante la clase.
#
# Vanessa es una científica de datos que está haciendo algunos análisis con datos ambientales. Está desarrollando un proyecto para evaluar el impacto ambiental de las actividades humanas en diferentes países del mundo, pero para ello necesita estimaciones de población de esos países. Al buscar en Internet, encontró una tabla de estimaciones de población en un artículo de la página de Wikipedia.
#
# Al igual que Vanessa, tu desafío es obtener un DataFrame de la tabla que contiene la información del número de habitantes de cada país.

# %%
#Leer archivo y convertirlo en dataframe
import pandas as pd

# Leer las tablas desde el archivo HTML/XML
df_list = pd.read_html("Anexo_Países.xml")

# Mostrar la primera tabla encontrada (la que contiene los países y sus datos)
df = df_list[0]
df.head()
# Out:
#   N.º País (o territorio dependiente)  \
# 0   1                           India
# 1   2                      China[12]​
# 2   3                  Estados Unidos
# 3   4                       Indonesia
# 4   5                        Pakistán
#
#   Proyección exponencial de la población al 1/7/2025[7]​ Total mun- dial (%)  \
# 0                                      1 417 492 000                    1754
# 1                                      1 407 934 000                    1742
# 2                                        342 181 000                     423
# 3                                        285 783 000                     354
# 4                                        256 204 000                     317
#
#   Cambio medio anual (%)[8]​ Cambio absoluto anual promedio  \
# 0                        090                     12 692 000
# 1                       -005                     -1 390 000
# 2                        061                      2 084 000
# ...

# %% [markdown]
# ## Aula 5 -Leyendo banco de datos

# %% [markdown]
# ### Creando un banco de datos local

# %%
# importar biblioteca SQL
import sqlalchemy

# %%
# Importar metodos de sql
from sqlalchemy import create_engine, MetaData, Table, inspect, text

# %%
# Crear motor para soportar tablas
engine = create_engine('sqlite:///:memory')

# %% [markdown]
# ### Escribiendo en un banco de datos

# %%
import pandas as pd

# %%
archivo = 'clientes_banco.csv'

# %%
# Hay que pasar el archivo a un dataframe para luego crear la base de datos
datos = pd.read_csv(archivo)

# %%
datos
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008809    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840104    62  Nivel intermedio        Divorciado               1
# 438459     6840222    43  Nivel intermedio           Soltero               1
# 438460     6841878    22    Nivel superior           Soltero               1
# 438461     6842765    59  Nivel intermedio            Casado               2
# 438462     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
datos.head(5)
# Out:
#    ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0     5008804    32    Nivel superior  Relación-estable               2
# 1     5008805    32    Nivel superior  Relación-estable               2
# 2     5008806    58  Nivel intermedio            Casado               2
# 3     5008808    52  Nivel intermedio           Soltero               1
# 4     5008809    52  Nivel intermedio           Soltero               1
#
#   Categoria_de_renta  Ocupacion  Años_empleado  Rendimiento_anual  \
# 0           Empleado       Otro             12           427500.0
# 1           Empleado       Otro             12           427500.0
# 2           Empleado  Seguridad              3           112500.0
# 3   Business Partner     Ventas              8           270000.0
# 4   Business Partner     Ventas              8           270000.0
#
#    Tiene_carro                  Vivienda
# 0            1    Departamento alquilado
# 1            1    Departamento alquilado
# ...

# %%
#Exportar a una tabla SQL, nombre a la tabla =cliente, segundo parametro el motor donde se encentra la base = engine, quitar indice como nueva columna
datos.to_sql('clientes', engine, index = False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-387-e0f69ef89c2c> in <cell line: 0>()
#       1 #Exportar a una tabla SQL, nombre a la tabla =cliente, segundo parametro el motor donde se encentra la base = engine, quitar indice como nueva columna
# ----> 2 datos.to_sql('clientes', engine, index = False)
#
# /usr/local/lib/python3.11/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     331                     stacklevel=find_stack_level(),
#     332                 )
# --> 333             return func(*args, **kwargs)
#     334
#     335         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    3085         from pandas.io import sql
#    3086
# ...

# %%
# como saber si creo una tabla dentro engine
inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes', 'empleados']

# %% [markdown]
# #### Para saber más: cláusulas SQL
#  Siguiente pregunta
#
# SQL (Structured Query Language - Lenguaje de consulta estructurado) es un lenguaje de consulta utilizado en bases de datos relacionales para insertar, actualizar, consultar y administrar datos.
#
# Para hacer todo esto, existen cláusulas SQL, que son componentes fundamentales de las sentencias SQL, permitiendo especificar detalles sobre cómo se va a realizar la consulta u operación de la base de datos. Las cláusulas se utilizan para filtrar, ordenar, agrupar y limitar los resultados de la consulta.
#
# Las sentencias SQL pueden estar compuestas por una o más cláusulas que proporcionan información adicional sobre lo que se supone que debe hacer la consulta. Las cláusulas más comunes son:
#
# * SELECT: especifica qué columnas deben seleccionarse en la consulta.
# * FROM: Especifica las tablas de la base de datos que se consultarán.
# * WHERE: Filtra los resultados de la consulta según una o más condiciones especificadas.
# * ORDER BY: Ordena los resultados de la consulta en orden ascendente o descendente según una o más columnas.
# * GROUP BY: agrupa los resultados de la consulta basados en una o más columnas.
# * LIMIT: limita el número de filas devueltas por los resultados de la consulta.

# %% [markdown]
# ## Leyendo una consulta SQL

# %%
# Realizar consultas
query = 'SELECT * FROM clientes WHERE categoria_de_renta = "Empleado"'

# %%
#consulta o como se lee
empleados= pd.read_sql(sql = text(query), con = engine.connect())

# %%
type(empleados)
# Out:
# pandas.core.frame.DataFrame

# %%
empleados
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
#Leer tabla completa
pd.read_sql_table('empleados', con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
# Leer filtrando algunas columnas
pd.read_sql_table('empleados', con = engine.connect(), columns =['ID_Cliente', 'Grado_estudio', 'Rendimiento_anual'] )
# Out:
#         ID_Cliente     Grado_estudio  Rendimiento_anual
# 0          5008804    Nivel superior           427500.0
# 1          5008805    Nivel superior           427500.0
# 2          5008806  Nivel intermedio           112500.0
# 3          5008815    Nivel superior           270000.0
# 4          5112956    Nivel superior           270000.0
# ...            ...               ...                ...
# 226054     6837905  Nivel intermedio           355050.0
# 226055     6837906  Nivel intermedio           355050.0
# 226056     6839936  Nivel intermedio           135000.0
# 226057     6840222  Nivel intermedio           103500.0
# 226058     6842885  Nivel intermedio           121500.0
#
# [226059 rows x 3 columns]

# %% [markdown]
# ### Actualizando un banco de datos

# %%
query = 'SELECT * FROM clientes'

# %%
pd.read_sql(sql=text(query), con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008809    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840104    62  Nivel intermedio        Divorciado               1
# 438459     6840222    43  Nivel intermedio           Soltero               1
# 438460     6841878    22    Nivel superior           Soltero               1
# 438461     6842765    59  Nivel intermedio            Casado               2
# 438462     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
# Como borrar un cliente
from sqlalchemy.exc import SQLAlchemyError
query = "DELETE FROM  clientes WHERE ID_Cliente = 5008804"
try:
  r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print("#Registros borrados: ", r_set.rowcount)
# Out:
# (sqlite3.OperationalError) database is locked
# [SQL: DELETE FROM  clientes WHERE ID_Cliente = 5008804]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#Vamos a confirmar
pd.read_sql_table('clientes', con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008809    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840104    62  Nivel intermedio        Divorciado               1
# 438459     6840222    43  Nivel intermedio           Soltero               1
# 438460     6841878    22    Nivel superior           Soltero               1
# 438461     6842765    59  Nivel intermedio            Casado               2
# 438462     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
#Actualizar registros
from sqlalchemy.exc import SQLAlchemyError
query = "UPDATE FROM  clientes SET Grado_estudio = 'Nivel superior' WHERE ID_Cliente = 5008808"
try:
  r_set = engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print("#Registros actualizados: ", r_set.rowcount)
# Out:
# (sqlite3.OperationalError) near "FROM": syntax error
# [SQL: UPDATE FROM  clientes SET Grado_estudio = 'Nivel superior' WHERE ID_Cliente = 5008808]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['clientes', 'empleados']

# %% [markdown]
# ### 09
# Desafío: manipulando una base de datos
#  Siguiente pregunta
#
# Es el momento de poner a prueba tus conocimientos adquiridos durante la clase.
#
# Usted es responsable de crear una base de datos local de clientes para una institución financiera. Disponemos del archivo CSV con los datos de los clientes.
#
# Tu misión es:
#
# 1. Crear la base de datos local con la biblioteca SQLAlchemy.
# 2. Escribir los datos del archivo CSV en esta base de datos local.
# 3. Realizar tres actualizaciones en la base de datos:
#
# * Actualizar el registro del cliente ID 6840104 cuyo rendimiento anual cambió a 300000.
# * Eliminar el registro de cliente ID 5008809, ya que esta persona ya no tiene cuenta en la institución financiera.
# * Crear un nuevo registro de cliente siguiendo las especificaciones a continuación:
# - ID_cliente: 6850985
# - Edad: 33
# - Grado_estudio: Doctorado
# - Estado_civil: Soltero
# - Tamaño_familia: 1
# - Categoria_de_renta: Empleado
# - Ocupacion: TI
# - Años_empleado: 2
# - Rendimiento_anual: 290000
# - Tiene_carro: 0
# - Vivienda: Casa/Departamento propio
#
# Consejo importante: Para agregar un nuevo cliente a la tabla, use la cláusula INSERT INTO seguida del nombre de la tabla y luego especifique los nombres de las columnas de la tabla entre paréntesis. Utilice la cláusula VALUES y luego pase entre paréntesis los nuevos valores para este nuevo registro. Asegúrese de que los valores estén en el orden correcto y en el formato adecuado para cada columna.
